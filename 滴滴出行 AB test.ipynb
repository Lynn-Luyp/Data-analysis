# %% [markdown]
# ## 滴滴出行A/B test（T检验）

# %% [markdown]
# 与一般的万行A/B test实验数据不同，本实验A/B组数据各自只有29行，只能使用T检验

# %% [markdown]
# ## 一、查看数据

# %% [markdown]
# 数据样本由58行，8列数据组成，数据较少，各字段名称及说明如下：
# - date：日期
# - group：组别
# - requests：订单请求数
# - gmv：成交总额
# - coupon per trip：每单优惠券金额
# - trips：订单数
# - canceled trips：取消请求数

# %% [markdown]
# ## 二、导入库

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %% [markdown]
# ## 三、导入数据

# %%
df=pd.read_excel(r'F:\Data\didi4010\test.xlsx')

# %% [markdown]
# ## 四、查看数据

# %%
df.head()
# Out:
#         date    group  requests         gmv  coupon per trip  trips  \
# 0 2019-01-01  control        30    7486.620         1.069746     24
# 1 2019-01-02  control       152   38301.575         1.044199    121
# 2 2019-01-03  control       267   67768.425         1.032276    215
# 3 2019-01-04  control       369   94992.900         1.028196    298
# 4 2019-01-05  control       478  123236.875         1.011807    390
#
#    canceled requests
# 0                  1
# 1                  8
# 2                 14
# 3                 19
# 4                 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               58 non-null     datetime64[ns]
#  1   group              58 non-null     object
#  2   requests           58 non-null     int64
#  3   gmv                58 non-null     float64
#  4   coupon per trip    58 non-null     float64
#  5   trips              58 non-null     int64
#  6   canceled requests  58 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(1)
# memory usage: 3.3+ KB

# %%
df.isnull().sum()
# Out:
# date                 0
# group                0
# requests             0
# gmv                  0
# coupon per trip      0
# trips                0
# canceled requests    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 五、数据清洗

# %% [markdown]
# 数据比较理想，不用预处理，现在对后几列数据查看

# %%
df[df.columns[2:]]
# Out:
#     requests          gmv  coupon per trip  trips  canceled requests
# 0         30     7486.620         1.069746     24                  1
# 1        152    38301.575         1.044199    121                  8
# 2        267    67768.425         1.032276    215                 14
# 3        369    94992.900         1.028196    298                 19
# 4        478   123236.875         1.011807    390                 24
# 5        579   148102.625         0.991845    476                 28
# 6        867   208075.975         0.938023    714                 42
# 7        963   233040.575         0.923250    795                 47
# 8       1064   258725.250         0.899881    873                 54
# 9       1183   287949.250         0.879014    965                 63
# 10      1289   314034.500         0.852589   1046                 71
# 11      1404   343593.750         0.845910   1136                 80
# 12      1540   375234.000         0.836576   1233                 99
# 13      2098   482983.250         0.756502   1658                162
# 14      2207   511808.000         0.748876   1747                169
# 15      2316   540765.250         0.740723   1833                177
# 16      2420   568005.750         0.732843   1916                185
# 17      2505   591686.750         0.726771   1985                190
# 18      2600   616598.750         0.723737   2062                196
# 19      2718   646505.250         0.736551   2155                207
# 20      3116   726422.250         0.749196   2475                238
# 21      3220   753117.250         0.755820   2559                246
# 22      3321   780021.500         0.764780   2639                253
# 23      3419   804938.250         0.769091   2717                261
# 24      3503   828042.750         0.773923   2787                266
# 25      3608   854086.250         0.780392   2871                273
# 26      3708   877773.250         0.786392   2950                282
# 27      4201   980150.500         0.790421   3345                322
# 28      4303  1005137.000         0.798622   3426                330
# 29        30     7382.210         1.039303     24                  1
# 30       152    36580.200         1.042920    123                  7
# 31       277    67626.375         1.034808    225                 13
# 32       383    94601.700         1.030538    311                 18
# 33       497   123388.850         1.025366    406                 24
# 34       602   149430.600         1.006147    493                 28
# 35       886   209840.625         0.955294    729                 40
# 36       986   235433.200         0.942042    812                 45
# 37      1083   260928.500         0.922505    890                 51
# 38      1201   290042.250         0.901899    982                 61
# 39      1312   318077.000         0.878583   1069                 70
# 40      1421   345412.750         0.861957   1156                 77
# 41      1555   375812.250         0.854074   1250                 99
# 42      2094   479094.250         0.765787   1657                159
# 43      2200   506663.750         0.756587   1743                167
# 44      2307   535324.000         0.747818   1827                174
# 45      2410   562010.500         0.740661   1912                180
# 46      2493   584459.250         0.734357   1980                185
# 47      2588   609191.000         0.730280   2057                191
# 48      2702   636740.500         0.740925   2148                201
# 49      3084   713343.750         0.755155   2456                231
# 50      3183   738668.500         0.760902   2537                237
# 51      3288   764081.750         0.767304   2618                246
# 52      3386   789127.250         0.773269   2697                252
# 53      3470   812143.250         0.777304   2765                258
# 54      3568   837921.750         0.784370   2844                265
# 55      3662   861041.750         0.788843   2920                272
# 56      4157   960759.000         0.790632   3312                314
# 57      4256   986233.750         0.797972   3392                320

# %%
df[df.columns[2:]].describe()
# Out:
#           requests           gmv  coupon per trip        trips  \
# count    58.000000  5.800000e+01        58.000000    58.000000
# mean   2046.224138  4.820680e+05         0.848199  1633.551724
# std    1287.778191  2.984599e+05         0.111335  1019.612227
# min      30.000000  7.382210e+03         0.723737    24.000000
# 25%     968.750000  2.336387e+05         0.756524   799.250000
# 50%    2203.500000  5.092359e+05         0.790527  1745.000000
# 75%    3210.750000  7.495051e+05         0.934330  2553.500000
# max    4303.000000  1.005137e+06         1.069746  3426.000000
#
#        canceled requests
# count          58.000000
# mean          146.431034
# std           104.260321
# min             1.000000
# 25%            45.500000
# 50%           168.000000
# 75%           244.000000
# max           330.000000

# %% [markdown]
# 数据没有问题

# %% [markdown]
# ## 六、查看group列

# %%
df.group.value_counts()
# Out:
# experiment    29
# control       29
# Name: group, dtype: int64

# %% [markdown]
# control表示的是对照组，experiment表示的是实验组，两个组都只有29行数据

# %% [markdown]
# ## 七、添加指标

# %% [markdown]
# 多加一列ROI(投资回报率)用于辅助我们进行判断
# 因为对于电商来说，增加优惠券或者其他操作，成本近似为0，所以认为利润=收入=gmv

# %% [markdown]
# ROI=利润/投资=利润/(原收入-现收入)=收入/(订单数* 每单优惠数)

# %%
df['ROI']=df.gmv/(df['coupon per trip']*df.trips)

# %%
# 查看数据
df.head()
# Out:
#         date    group  requests         gmv  coupon per trip  trips  \
# 0 2019-01-01  control        30    7486.620         1.069746     24
# 1 2019-01-02  control       152   38301.575         1.044199    121
# 2 2019-01-03  control       267   67768.425         1.032276    215
# 3 2019-01-04  control       369   94992.900         1.028196    298
# 4 2019-01-05  control       478  123236.875         1.011807    390
#
#    canceled requests         ROI
# 0                  1  291.604269
# 1                  8  303.143166
# 2                 14  305.346684
# 3                 19  310.026761
# 4                 24  312.304607

# %% [markdown]
# ## 八、requests 假设检验

# %% [markdown]
# 由于样本数<30，选用t检验对requests进行检验

# %% [markdown]
# 由于设置了对照组和实验组，我认为两组对象应该是独立对象，对独立对象进行t检验需要先检验其是否齐方差

# %% [markdown]
# ### 齐方差检验

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令对照组方差为c1，实验组方差为c2
# 零假设H<sub>0</sub>：c1=c2
# 备择假设H<sub>1</sub>：c1<>c2

# %% [markdown]
# #### 判断方差齐性

# %%
requests_A=df[df.group=='control'].requests
requests_A
# Out:
# 0       30
# 1      152
# 2      267
# 3      369
# 4      478
# 5      579
# 6      867
# 7      963
# 8     1064
# 9     1183
# 10    1289
# 11    1404
# 12    1540
# 13    2098
# 14    2207
# 15    2316
# 16    2420
# 17    2505
# 18    2600
# 19    2718
# 20    3116
# 21    3220
# 22    3321
# 23    3419
# 24    3503
# 25    3608
# 26    3708
# 27    4201
# 28    4303
# Name: requests, dtype: int64

# %%
requests_B=df[df.group=='experiment'].requests
requests_B
# Out:
# 29      30
# 30     152
# 31     277
# 32     383
# 33     497
# 34     602
# 35     886
# 36     986
# 37    1083
# 38    1201
# 39    1312
# 40    1421
# 41    1555
# 42    2094
# 43    2200
# 44    2307
# 45    2410
# 46    2493
# 47    2588
# 48    2702
# 49    3084
# 50    3183
# 51    3288
# 52    3386
# 53    3470
# 54    3568
# 55    3662
# 56    4157
# 57    4256
# Name: requests, dtype: int64

# %%
import scipy.stats as st
st.levene(requests_A,requests_B)
# Out:
# LeveneResult(statistic=0.014685075667736849, pvalue=0.903980667108546)

# %% [markdown]
# 因为pvalue=0.904>α=0.05，我们接受H<sub>0</sub>，拒绝H<sub>1</sub>
# 所以我们认为c1=c2，也就是两者是齐方差

# %% [markdown]
# ### requests检验

# %% [markdown]
# 查看两者均值

# %%
requests_A.mean()
# Out:
# 2049.9310344827586

# %%
requests_B.mean()
# Out:
# 2042.5172413793102

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令A组均值为u1，B组均值为u2

# %% [markdown]
# H<sub>0</sub>：u1=u2
# H<sub>1</sub>：u1<>u2

# %% [markdown]
# #### 确定假设检验方向

# %% [markdown]
# 使用双尾

# %% [markdown]
# #### 确定检验类型和统计量

# %% [markdown]
# 由之前的过程，我们使用t检验，并且t检验为齐方差检验

# %% [markdown]
# #### 确定显著性水平α

# %% [markdown]
# 令α=0.05

# %% [markdown]
# #### 假设检验过程

# %%
# 导入库
from scipy.stats import ttest_ind

# %%
ttest_ind(requests_A,requests_B)
# Out:
# Ttest_indResult(statistic=0.021729103766715982, pvalue=0.9827412881046896)

# %% [markdown]
# 得到p=0.983>α，接受H<sub>0</sub>，拒绝H<sub>1</sub>

# %% [markdown]
# 我们得到结论，实验条件对requests影响不大

# %% [markdown]
# ## 九、gmv检验

# %% [markdown]
# 由于样本数<30，选用t检验对gmv进行检验

# %% [markdown]
# 由于设置了对照组和实验组，我认为两组对象应该是独立对象，对独立对象进行t检验需要先检验其是否齐方差

# %% [markdown]
# ### 齐方差检验

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令对照组方差为c1，实验组方差为c2
# 零假设H0：c1=c2
# 备择假设H1：c1<>c2

# %% [markdown]
# #### 判断方差齐性

# %%
requests_A=df[df.group=='control'].gmv
requests_A
# Out:
# 0        7486.620
# 1       38301.575
# 2       67768.425
# 3       94992.900
# 4      123236.875
# 5      148102.625
# 6      208075.975
# 7      233040.575
# 8      258725.250
# 9      287949.250
# 10     314034.500
# 11     343593.750
# 12     375234.000
# 13     482983.250
# 14     511808.000
# 15     540765.250
# 16     568005.750
# 17     591686.750
# 18     616598.750
# 19     646505.250
# 20     726422.250
# 21     753117.250
# 22     780021.500
# 23     804938.250
# 24     828042.750
# 25     854086.250
# 26     877773.250
# 27     980150.500
# 28    1005137.000
# Name: gmv, dtype: float64

# %%
requests_B=df[df.group=='experiment'].gmv
requests_B
# Out:
# 29      7382.210
# 30     36580.200
# 31     67626.375
# 32     94601.700
# 33    123388.850
# 34    149430.600
# 35    209840.625
# 36    235433.200
# 37    260928.500
# 38    290042.250
# 39    318077.000
# 40    345412.750
# 41    375812.250
# 42    479094.250
# 43    506663.750
# 44    535324.000
# 45    562010.500
# 46    584459.250
# 47    609191.000
# 48    636740.500
# 49    713343.750
# 50    738668.500
# 51    764081.750
# 52    789127.250
# 53    812143.250
# 54    837921.750
# 55    861041.750
# 56    960759.000
# 57    986233.750
# Name: gmv, dtype: float64

# %%
import scipy.stats as st
st.levene(requests_A,requests_B)
# Out:
# LeveneResult(statistic=0.02865341299111212, pvalue=0.8661917430097603)

# %% [markdown]
# 因为pvalue=0.866>α=0.05，我们接受H<sub>0</sub>，拒绝H<sub>1</sub>
# 所以我们认为c1=c2，也就是两者是齐方差

# %% [markdown]
# ###  gmv检验

# %% [markdown]
# 查看两者均值

# %%
requests_A.mean()
# Out:
# 485123.5972413793

# %%
requests_B.mean()
# Out:
# 479012.4313793103

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令A组均值为u1，B组均值为u2

# %% [markdown]
# H<sub>0</sub>：u1=u2

# %% [markdown]
# H<sub>1</sub>：u1<>u2

# %% [markdown]
# #### 确定假设检验方向

# %% [markdown]
# 使用双尾

# %% [markdown]
# #### 确定检验类型和统计量

# %% [markdown]
# 由之前的过程，我们使用t检验，并且t检验为齐方差检验

# %% [markdown]
# #### 确定显著性水平α

# %% [markdown]
# 令α=0.05

# %% [markdown]
# #### 假设检验过程

# %%
# 导入库
from scipy.stats import ttest_ind

# %%
ttest_ind(requests_A,requests_B)
# Out:
# Ttest_indResult(statistic=0.07728616692818668, pvalue=0.9386713733961323)

# %% [markdown]
# 得到p=0.938>α，接受H<sub>0</sub>，拒绝H<sub>1</sub>

# %% [markdown]
# 我们得到结论，实验条件对gmv影响不大

# %% [markdown]
# #### 误差分析

# %% [markdown]
# 注：如果把实验对象当作相关性对象检测，结果为：

# %%
st.ttest_rel(requests_A,requests_B)
# Out:
# Ttest_relResult(statistic=4.247583846321442, pvalue=0.00021564303983362577)

# %% [markdown]
# 这里的0.0002更加合理，但是这里我将两个数据当作独立数据考虑，进行t检验

# %% [markdown]
# ## 十、ROI检验

# %% [markdown]
# 由于样本数<30，选用t检验对gmv进行检验

# %% [markdown]
# 由于设置了对照组和实验组，我认为两组对象应该是独立对象，对独立对象进行t检验需要先检验其是否齐方差

# %% [markdown]
# ### 齐方差检验

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令对照组方差为c1，实验组方差为c2
# 零假设H<sub>0</sub>：c1=c2
# 备择假设H<sub>1</sub>：c1<>c2

# %% [markdown]
# #### 判断方差齐性

# %%
requests_A=df[df.group=='control'].ROI
requests_A
# Out:
# 0     291.604269
# 1     303.143166
# 2     305.346684
# 3     310.026761
# 4     312.304607
# 5     313.698098
# 6     310.677730
# 7     317.500829
# 8     329.336306
# 9     339.463217
# 10    352.132476
# 11    357.554820
# 12    363.775826
# 13    385.067775
# 14    391.205131
# 15    398.281549
# 16    404.525992
# 17    410.141385
# 18    413.174493
# 19    407.307217
# 20    391.758812
# 21    389.380259
# 22    386.483110
# 23    385.207786
# 24    383.900057
# 25    381.202612
# 26    378.373959
# 27    370.713305
# 28    367.364146
# Name: ROI, dtype: float64

# %%
requests_B=df[df.group=='experiment'].ROI
requests_B
# Out:
# 29    295.960040
# 30    285.160963
# 31    290.451626
# 32    295.171509
# 33    296.395066
# 34    301.253014
# 35    301.318100
# 36    307.780638
# 37    317.806505
# 38    327.485256
# 39    338.666227
# 40    346.653174
# 41    352.018340
# 42    377.564021
# 43    384.205494
# 44    391.816340
# 45    396.859893
# 46    401.959183
# 47    405.536343
# 48    400.086547
# 49    384.622243
# 50    382.648953
# 51    380.367029
# 52    378.386379
# 53    377.873886
# 54    375.623503
# 55    373.809886
# 56    366.901602
# 57    364.364529
# Name: ROI, dtype: float64

# %%
import scipy.stats as st
st.levene(requests_A,requests_B)
# Out:
# LeveneResult(statistic=0.10363884745479335, pvalue=0.7487044961896305)

# %% [markdown]
# 因为pvalue=0.748>α=0.05，我们接受H<sub>0</sub>，拒绝H<sub>1</sub>
# 所以我们认为c1=c2，也就是两者是齐方差

# %% [markdown]
# #### ROI检验

# %% [markdown]
# 查看两者均值

# %%
requests_A.mean()
# Out:
# 360.3673233425277

# %%
requests_B.mean()
# Out:
# 351.68090647475714

# %% [markdown]
# #### 零假设

# %% [markdown]
# 令A组均值为u1，B组均值为u2

# %% [markdown]
# H<sub>0</sub>：u1=u2

# %% [markdown]
# H<sub>1</sub>：u1<>u2

# %% [markdown]
# #### 确定假设检验方向

# %% [markdown]
# 使用双尾

# %% [markdown]
# #### 确定检验类型和统计量

# %% [markdown]
# 由之前的过程，我们使用t检验，并且t检验为齐方差检验

# %% [markdown]
# #### 确定显著性水平α

# %% [markdown]
# 令α=0.05

# %% [markdown]
# #### 假设检验过程

# %%
# 导入库
from scipy.stats import ttest_ind

# %%
ttest_ind(requests_A,requests_B)
# Out:
# Ttest_indResult(statistic=0.8430996450057455, pvalue=0.40275951535453325)

# %% [markdown]
# 得到p=0.402>α=0.05，接受H<sub>0</sub>，拒绝H<sub>1</sub>
# 我们得到结论，实验条件对ROI影响不大

# %% [markdown]
# ## 十一、结论

# %% [markdown]
# 经过我查找资料之后，结论如下：
# 配对检验是基于对同一样本中相同个体的多次测量数据的检验
# 独立检验是对于不同样本的个体的测量数据

# %% [markdown]
# 本实验的结果比较不合理，原因在于数据集中并没有注明两组实验是配对样本还是独立样本
# 我理解的样本是A/B组独立进行实验，所以结论都建立在两者为独立样本的基础上进行的

# %% [markdown]
# 所以实验结果显示，行为措施对ROI影响不大
