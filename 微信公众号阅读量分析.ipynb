# %% [markdown]
# # 可视化国内微信公众号的情况

# %% [markdown]
# ## 一、查看数据

# %% [markdown]
# 数据有由500行，9列组成，包括公众号的详细信息

# %% [markdown]
# ## 二、导入库

# %%
import matplotlib as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# ## 三、导入数据

# %%
path=r'F:\Data\微信\微信月榜.csv'
df=pd.read_csv(path)

# %% [markdown]
# ## 四、查看数据

# %%
df.head()
# Out:
#    排名     公众号名称  四月发布文章数  总发布文章数      总阅读数        头条  平均阅读数   总在看人数  \
# 0   1      央视财经      281     653  42963614  25720124  65794  232056
# 1   2   杭州交通918      204    1617  50761960  18606407  31392  168199
# 2   3     中国经济网      229     694  38498466  19719121  55473  253831
# 3   4  广东公共DV现场      174     793  38669882  16350001  48764  109758
# 4   5      丁香医生       90     334  28531819   9000000  85424  345631
#
#           新榜指数
# 0  1021.315363
# 1  1020.068729
# 2  1014.404743
# 3  1009.999658
# 4  1003.353114

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   排名       500 non-null    int64
#  1   公众号名称    500 non-null    object
#  2   四月发布文章数  500 non-null    int64
#  3   总发布文章数   500 non-null    int64
#  4   总阅读数     500 non-null    int64
#  5   头条       500 non-null    int64
#  6   平均阅读数    500 non-null    int64
#  7   总在看人数    500 non-null    int64
#  8   新榜指数     500 non-null    float64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 35.3+ KB

# %% [markdown]
# ## 数据清洗

# %% [markdown]
# ### 取前20行数据进行分析

# %%
top20=df.head(20)

# %%
top20['新榜指数']=np.round(top20['新榜指数'],2)
# Out:
# <ipython-input-14-347cb7494aa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top20['新榜指数']=np.round(top20['新榜指数'],2)

# %%
top20
# Out:
#     排名     公众号名称  四月发布文章数  总发布文章数      总阅读数        头条  平均阅读数    总在看人数     新榜指数
# 0    1      央视财经      281     653  42963614  25720124  65794   232056  1021.32
# 1    2   杭州交通918      204    1617  50761960  18606407  31392   168199  1020.07
# 2    3     中国经济网      229     694  38498466  19719121  55473   253831  1014.40
# 3    4  广东公共DV现场      174     793  38669882  16350001  48764   109758  1010.00
# 4    5      丁香医生       90     334  28531819   9000000  85424   345631  1003.35
# 5    6      中国搜索      292     814  30824726  18586289  37868   274905  1001.35
# 6    7        洞见       30     240  23731288   3000000  98880  1968140   998.73
# 7    8        占豪       30     239  23678522   3000000  99073  1457004   997.63
# 8    9      十点读书       30     240  23403725   3000000  97515  1152747   996.18
# 9   10       新晚报      181    1217  32227479  12906280  26481    94741   995.36
# 10  11        有书       30     236  23313932   3000000  98787   917362   995.34
# ...

# %%
top20_1=top20.groupby(['公众号名称'])['新榜指数'].sum().sort_values(ascending=False)

# %% [markdown]
# ### 数据查重

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 无重复数据

# %% [markdown]
# ## 保存数据

# %%
df.to_csv(r'F:\Data\微信\微信done.csv',index=None,encoding='utf_8_sig')

# %% [markdown]
# ## 可视化分析

# %% [markdown]
# ### 新榜指数与在看人数排行榜

# %% [markdown]
# ![](http://m.qpic.cn/psc?/V509KgjP2rVc1x3xXZE72dVD4k46B5pi/ruAMsa53pVQWN7FLK88i5qW0cOX6jAUO1WYTdFJdrwxAyhKMoBv0erBsKqtcq4bdhhKzd3gya5jXa3krFDlJ29S9bWPzXQTGffyhG9kPqLY!/b&bo=YwT7AWME.wEDCSw!&rf=viewer_4)

# %% [markdown]
# ### 平均阅读数

# %% [markdown]
# ![](http://m.qpic.cn/psc?/V509KgjP2rVc1x3xXZE72dVD4k46B5pi/ruAMsa53pVQWN7FLK88i5qW0cOX6jAUO1WYTdFJdrwyVMWi4knewOO*0BZaXRXDKDzG1QXUPVxxgAsBsZYVdXv5xOcSJurYZtyOIFCgMy64!/b&bo=YwQkAmMEJAIDCSw!&rf=viewer_4)

# %% [markdown]
# ### 当月发布文章与总文章之比

# %% [markdown]
# ![](http://m.qpic.cn/psc?/V509KgjP2rVc1x3xXZE72dVD4k46B5pi/45NBuzDIW489QBoVep5mcfrcNKc8jUVhsYqc0JF2Etz8Q8u8UmR48ibmbCClQNF0.PhkTUby5BIjVBOgnGzuYsik3gf8*qV50R9Xh3kT9Cg!/b&bo=wgMkAsIDJAIDGTw!&rf=viewer_4)
